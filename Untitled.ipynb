# %%
from gym import Env
from gym.spaces import Discrete, Box
import numpy as np
import random
from matplotlib import pyplot as plt
import matplotlib.animation
from IPython.display import display, clear_output
import random
import pygame

# %%
# x = np.arange(1, 10, 1)
# y = np.arange(1, 10, 1)
# i=0
logs = {1000: -308.8078342331893,
 5000: -143.2580174170538,
 10000: -155.78609127837154,
 15000: -149.57824776422228,
 20000: -228.72297844445487,
 25000: -204.61390880288442,
 35000: -159.23455552933467,
 45000: -157.56615966927995}

x = list(logs.keys())
y = list(logs.values())


plt.figure(figsize=(10,6))
plt.plot(x, y, label=f'Strategie {i}')
plt.xlabel('Model Checkpoint')
plt.ylabel('Mean Validation Reward')
plt.title('Choosing Reward')
plt.legend()
plt.grid()

# %%
print(x)
print(y)
# Out:
# [1000, 5000, 10000, 15000, 20000, 25000, 35000, 45000]
# [-308.8078342331893, -143.2580174170538, -155.78609127837154, -149.57824776422228, -228.72297844445487, -204.61390880288442, -159.23455552933467, -157.56615966927995]

# %%
x = [1000, 5000, 10000, 15000, 20000, 25000, 35000, 45000]
y3 = [-308, -143, -155, -149, -168, -178, -159, -157]
y1 = [-380, -280, -220, -217, -228, -224, -229, -217]
y2 = [-400, -310, -265, -247, -239, -253, -240, -247]
y4 = [-328, -163, -164, -165, -188, -184, -173, -173]

y_ = [-333.8648923996682, -281.39773406147486, -293.11126799543183, -312.95515351060504, -304, -314, -324, -294]

# %%
plt.figure(figsize=(10,6))
for i, y in zip(['Baseline', 'Compressed'], [y3, y_]):
    
    
    plt.plot(x, y, label=f'Model {i}')
    plt.xlabel('Model Checkpoint')
    plt.ylabel('- Mean Validation Distance')
    plt.title('Choosing Architecture')
plt.legend()
plt.grid()

# %%
{1000: -333.8648923996682,
 5000: -281.39773406147486,
 10000: -293.11126799543183,
 15000: -312.95515351060504}.values()

# %%
Dense(1024, activation='relu')
Dense(100, activation='relu')
Dense(n_actions, activation='linear')
